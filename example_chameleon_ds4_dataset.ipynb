# %%
import time
from denmune import DenMune

# %%
verpose_mode = True
dataset = 'cham_04' # let us take Chameleon DS4 dataset as an example
data_path = 'data/' #change it to whatever you put your data, set it to ''; so it will retrive from current folder

start = step = 1
end = max_knn  = 50

for n in range(start, end+1, step):
    start = time.time()
    py = DenMune(dataset=dataset, k_nearest=n, data_path=data_path, verpose=verpose_mode)
    labels_true, labels_pred = py.output_Clusters()
    end = time.time()
    
    print('k=' , n, "=====" * 20 , '\n')
# Out:
# using NGT, Proximity matrix has been calculated  in:  0.1243751049041748  seconds
# k= 1 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.20727181434631348  seconds
# k= 2 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2594618797302246  seconds
# k= 3 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.19144129753112793  seconds
# k= 4 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.18880414962768555  seconds
# k= 5 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.26451563835144043  seconds
# k= 6 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.17005515098571777  seconds
# k= 7 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.17917275428771973  seconds
# k= 8 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.23842835426330566  seconds
# k= 9 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2452678680419922  seconds
# k= 10 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.21210265159606934  seconds
# k= 11 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.25708746910095215  seconds
# k= 12 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.26010608673095703  seconds
# k= 13 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2682228088378906  seconds
# k= 14 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.25400233268737793  seconds
# k= 15 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.29823970794677734  seconds
# k= 16 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.37592411041259766  seconds
# k= 17 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3380444049835205  seconds
# k= 18 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.37274169921875  seconds
# k= 19 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3209683895111084  seconds
# k= 20 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3118472099304199  seconds
# k= 21 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.35894060134887695  seconds
# k= 22 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.304171085357666  seconds
# k= 23 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.364027738571167  seconds
# k= 24 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3229203224182129  seconds
# k= 25 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3290283679962158  seconds
# k= 26 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3530600070953369  seconds
# k= 27 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3430352210998535  seconds
# k= 28 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4074990749359131  seconds
# k= 29 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.41062402725219727  seconds
# k= 30 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.41043686866760254  seconds
# k= 31 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4290738105773926  seconds
# k= 32 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3711690902709961  seconds
# k= 33 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.43657422065734863  seconds
# k= 34 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3965029716491699  seconds
# k= 35 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.43357276916503906  seconds
# k= 36 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4084477424621582  seconds
# k= 37 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.47133684158325195  seconds
# k= 38 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.48015904426574707  seconds
# k= 39 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.42826223373413086  seconds
# k= 40 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4851839542388916  seconds
# k= 41 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4385347366333008  seconds
# k= 42 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4795515537261963  seconds
# k= 43 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.5128450393676758  seconds
# k= 44 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.5449881553649902  seconds
# k= 45 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4643707275390625  seconds
# k= 46 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.5202510356903076  seconds
# k= 47 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.5119867324829102  seconds
# k= 48 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.5886046886444092  seconds
# k= 49 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4868474006652832  seconds
# k= 50 ====================================================================================================
