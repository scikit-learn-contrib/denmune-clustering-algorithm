# %%
import time
import pandas as pd
from numpy import genfromtxt
from denmune import DenMune

# %%
# Denmune's Paramaters
# DenMune(dataset=dataset, k_nearest=n, data_path=data_path, verpose=verpose_mode, show_plot=show_plot, show_noise=show_noise)
dataset = 'compound' # let us take Compound dataset as an example
verpose_mode = True # view in-depth analysis of time complexity and outlier detection, num of clusters
data_path = 'data/' # change it to whatever you put your data, set it to ''; so it will retrive from current folder
show_plot = True  # show plots on/off
show_noise = True # show noise and outlier on/off

# loop's parameters
start = 1
step = 1
end=15

# Validity indexes' parameters
validity_val = -1
best_k = 0
best_val = -1

validity_idx = 2 # Acc=1, F1-score=2,  NMI=3, AMI=4, ARI=5,  Homogeneity=6, and Completeness=7
df = pd.DataFrame(columns =['K', 'ACC', 'F1', 'NMI', 'AMI', 'ARI','Homogeneity', 'Completeness', 'Time' ])


for n in range(start, end+1, step):
    start_time = time.time()
    dm = DenMune(dataset=dataset, k_nearest=n, data_path=data_path, verpose=verpose_mode, show_noise=show_noise)
    labels_true, labels_pred = dm.output_Clusters()
    if show_plot == True and n==start:
        # Let us plot the groundtruth of this dataset which is reduced to 2-d using t-SNE
        print ("Dataset\'s Groundtruht")
        dm.plot_clusters(labels_true, ground=True)
        print('\n', "=====" * 20 , '\n')       
               
    end_time = time.time()
    
    validity_indexes = dm.validate_Clusters(labels_true, labels_pred)
    validity_val = validity_indexes[validity_idx]
    validity_indexes[0] = n
    validity_indexes[8] = end_time - start_time
    
    df = df.append(pd.Series(validity_indexes, index=df.columns ), ignore_index=True)
    
    if (best_val < validity_val):
        best_val = validity_val
        best_k = n
        # Let us show results where only an improve in accuracy is detected
        if show_plot:
            dm.plot_clusters(labels_pred, show_noise=show_noise)
    print ('k=' , n, ':Validity score is:', validity_val , 'but best score is', best_val, 'at k=', best_k , end='     ')
            
    if not verpose_mode:
        print('\r', end='')
    else:
        print('\n', "=====" * 20 , '\n')
# Out:
# using NGT, Proximity matrix has been calculated  in:  0.005796194076538086  seconds
# Dataset's Groundtruht
#  ====================================================================================================
#
# There are 0 outlier point(s) in black (noise of type-1) represent 0% of total points
# There are 0 weak point(s) in light grey (noise of type-2) represent 0% of total points
# DenMune detected 93 clusters
# k= 1 :Validity score is: 0.1613685688752713 but best score is 0.1613685688752713 at k= 1
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.004778146743774414  seconds
# There are 0 outlier point(s) in black (noise of type-1) represent 0% of total points
# There are 0 weak point(s) in light grey (noise of type-2) represent 0% of total points
# DenMune detected 81 clusters
# k= 2 :Validity score is: 0.1929813060110071 but best score is 0.1929813060110071 at k= 2
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.00543975830078125  seconds
# There are 12 outlier point(s) in black (noise of type-1) represent 3% of total points
# There are 0 weak point(s) in light grey (noise of type-2) represent 0% of total points
# DenMune detected 39 clusters
# k= 3 :Validity score is: 0.4833863898240931 but best score is 0.4833863898240931 at k= 3
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.005402088165283203  seconds
# There are 3 outlier point(s) in black (noise of type-1) represent 1% of total points
# There are 0 weak point(s) in light grey (noise of type-2) represent 0% of total points
# DenMune detected 13 clusters
# k= 4 :Validity score is: 0.9220715164504741 but best score is 0.9220715164504741 at k= 4
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.004243373870849609  seconds
# k= 5 :Validity score is: 0.9117910071782166 but best score is 0.9220715164504741 at k= 4
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.004125833511352539  seconds
# k= 6 :Validity score is: 0.7970062518934701 but best score is 0.9220715164504741 at k= 4
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.004330873489379883  seconds
# There are 1 outlier point(s) in black (noise of type-1) represent 0% of total points
# There are 0 weak point(s) in light grey (noise of type-2) represent 0% of total points
# DenMune detected 7 clusters
# k= 7 :Validity score is: 0.9489018801904978 but best score is 0.9489018801904978 at k= 7
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.0062541961669921875  seconds
# k= 8 :Validity score is: 0.9199402153515593 but best score is 0.9489018801904978 at k= 7
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.004956960678100586  seconds
# k= 9 :Validity score is: 0.9176884834779572 but best score is 0.9489018801904978 at k= 7
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.00653076171875  seconds
# k= 10 :Validity score is: 0.9344839420589544 but best score is 0.9489018801904978 at k= 7
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.06098151206970215  seconds
# There are 0 outlier point(s) in black (noise of type-1) represent 0% of total points
# There are 0 weak point(s) in light grey (noise of type-2) represent 0% of total points
# DenMune detected 8 clusters
# k= 11 :Validity score is: 0.9562966162181592 but best score is 0.9562966162181592 at k= 11
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.0052490234375  seconds
# There are 0 outlier point(s) in black (noise of type-1) represent 0% of total points
# There are 0 weak point(s) in light grey (noise of type-2) represent 0% of total points
# DenMune detected 8 clusters
# k= 12 :Validity score is: 0.9583963373437057 but best score is 0.9583963373437057 at k= 12
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.005501985549926758  seconds
# There are 0 outlier point(s) in black (noise of type-1) represent 0% of total points
# There are 0 weak point(s) in light grey (noise of type-2) represent 0% of total points
# DenMune detected 7 clusters
# k= 13 :Validity score is: 0.9828443022951031 but best score is 0.9828443022951031 at k= 13
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.005884408950805664  seconds
# k= 14 :Validity score is: 0.9154056568327119 but best score is 0.9828443022951031 at k= 13
#  ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.006308078765869141  seconds
# k= 15 :Validity score is: 0.9230266102453776 but best score is 0.9828443022951031 at k= 13
#  ====================================================================================================

# %%
# It is time to save the results
para_file = 'results/denmune'+ '_para_'  + dataset + '.csv'
df.sort_values(by=['F1', 'NMI', 'ARI'] , ascending=False, inplace=True)   
df.to_csv(para_file, index=False, sep='\t', header=True)

# %%
df # it is sorted now and saved
# Out:
#        K    ACC        F1       NMI       AMI       ARI  Homogeneity  \
# 12  13.0  389.0  0.982844  0.961066  0.960046  0.979710     0.976055
# 11  12.0  375.0  0.958396  0.943510  0.941812  0.967203     0.976055
# 10  11.0  374.0  0.956297  0.944282  0.942599  0.966414     0.977895
# 6    7.0  376.0  0.948902  0.928274  0.926205  0.953971     0.945936
# 9   10.0  371.0  0.934484  0.913639  0.911363  0.938031     0.921441
# 14  15.0  376.0  0.923027  0.912829  0.911253  0.889408     0.870535
# 3    4.0  355.0  0.922072  0.890091  0.884409  0.942317     0.964909
# 7    8.0  364.0  0.919940  0.916355  0.913782  0.946772     0.944911
# 8    9.0  363.0  0.917688  0.911032  0.908294  0.943695     0.939011
# 13  14.0  373.0  0.915406  0.895426  0.893533  0.880251     0.853352
# 4    5.0  355.0  0.911791  0.897926  0.893599  0.945619     0.959201
# 5    6.0  326.0  0.797006  0.865291  0.861214  0.880238     0.850577
# 2    3.0  142.0  0.483386  0.607748  0.561940  0.279608     0.926350
# 1    2.0   53.0  0.192981  0.468249  0.355580  0.050836     0.833552
# 0    1.0   76.0  0.161369  0.320910  0.126086 -0.033496     0.445108
#
#     Completeness      Time
# 12      0.946530  0.053261
# 11      0.913065  0.049349
# 10      0.912903  0.104585
# 6       0.911259  0.043987
# 9       0.905968  0.046664
# 14      0.959442  0.111995
# 3       0.826040  0.120553
# 7       0.889474  0.043665
# 8       0.884671  0.042568
# 13      0.941864  0.058814
# 4       0.844010  0.035665
# 5       0.880523  0.037585
# 2       0.452216  0.046212
# 1       0.325569  0.046958
# 0       0.250902  0.150289
