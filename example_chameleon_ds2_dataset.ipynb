# %%
import time
from denmune import DenMune

# %%
verpose_mode = True
dataset = 'cham_02' # let us take Chameleon DS2 dataset as an example
data_path = 'data/' #change it to whatever you put your data, set it to ''; so it will retrive from current folder

start = step = 1
end = max_knn  = 50

for n in range(start, end+1, step):
    start = time.time()
    py = DenMune(dataset=dataset, k_nearest=n, data_path=data_path, verpose=verpose_mode)
    labels_true, labels_pred = py.output_Clusters()
    end = time.time()
    
    print('k=' , n, "=====" * 20 , '\n')
# Out:
# using NGT, Proximity matrix has been calculated  in:  0.10529565811157227  seconds
# k= 1 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.17831683158874512  seconds
# k= 2 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.14333176612854004  seconds
# k= 3 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.13686513900756836  seconds
# k= 4 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.13131952285766602  seconds
# k= 5 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.12168216705322266  seconds
# k= 6 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.16265296936035156  seconds
# k= 7 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.25399088859558105  seconds
# k= 8 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.1813344955444336  seconds
# k= 9 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.1457078456878662  seconds
# k= 10 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.18403267860412598  seconds
# k= 11 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2701587677001953  seconds
# k= 12 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.17090082168579102  seconds
# k= 13 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.17306971549987793  seconds
# k= 14 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.22554469108581543  seconds
# k= 15 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2320854663848877  seconds
# k= 16 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.23143863677978516  seconds
# k= 17 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.24028706550598145  seconds
# k= 18 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.21614551544189453  seconds
# k= 19 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2678542137145996  seconds
# k= 20 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.23766207695007324  seconds
# k= 21 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.23953604698181152  seconds
# k= 22 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.21583986282348633  seconds
# k= 23 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.22960615158081055  seconds
# k= 24 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.24494123458862305  seconds
# k= 25 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2852957248687744  seconds
# k= 26 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.30396246910095215  seconds
# k= 27 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.30443859100341797  seconds
# k= 28 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.30216217041015625  seconds
# k= 29 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.260012149810791  seconds
# k= 30 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3038811683654785  seconds
# k= 31 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.28347086906433105  seconds
# k= 32 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2942681312561035  seconds
# k= 33 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.32663655281066895  seconds
# k= 34 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.33133864402770996  seconds
# k= 35 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3454437255859375  seconds
# k= 36 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3232543468475342  seconds
# k= 37 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.35491394996643066  seconds
# k= 38 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3306257724761963  seconds
# k= 39 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.37801527976989746  seconds
# k= 40 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.34342193603515625  seconds
# k= 41 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.37449002265930176  seconds
# k= 42 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3698136806488037  seconds
# k= 43 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.40029335021972656  seconds
# k= 44 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3838484287261963  seconds
# k= 45 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3557617664337158  seconds
# k= 46 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4170525074005127  seconds
# k= 47 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4103834629058838  seconds
# k= 48 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4128596782684326  seconds
# k= 49 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.477522611618042  seconds
# k= 50 ====================================================================================================
