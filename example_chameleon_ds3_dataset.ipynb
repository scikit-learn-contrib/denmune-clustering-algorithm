# %%
import time
from denmune import DenMune

# %%
verpose_mode = True
dataset = 'cham_03' # let us take Chameleon DS3 dataset as an example
data_path = 'data/' #change it to whatever you put your data, set it to ''; so it will retrive from current folder

start = step = 1
end = max_knn  = 50

for n in range(start, end+1, step):
    start = time.time()
    py = DenMune(dataset=dataset, k_nearest=n, data_path=data_path, verpose=verpose_mode)
    labels_true, labels_pred = py.output_Clusters()
    end = time.time()
    
    print('k=' , n, "=====" * 20 , '\n')
# Out:
# using NGT, Proximity matrix has been calculated  in:  0.09734702110290527  seconds
# k= 1 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.19832730293273926  seconds
# k= 2 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.10864710807800293  seconds
# k= 3 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.11077594757080078  seconds
# k= 4 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.11341595649719238  seconds
# k= 5 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.15897631645202637  seconds
# k= 6 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.17223787307739258  seconds
# k= 7 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.226914644241333  seconds
# k= 8 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.14983367919921875  seconds
# k= 9 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.15009236335754395  seconds
# k= 10 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.19260001182556152  seconds
# k= 11 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2680075168609619  seconds
# k= 12 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.19037079811096191  seconds
# k= 13 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.17189860343933105  seconds
# k= 14 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.22283339500427246  seconds
# k= 15 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.22528815269470215  seconds
# k= 16 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.21116209030151367  seconds
# k= 17 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.21582627296447754  seconds
# k= 18 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2250359058380127  seconds
# k= 19 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2531139850616455  seconds
# k= 20 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2262270450592041  seconds
# k= 21 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.22687387466430664  seconds
# k= 22 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.25434446334838867  seconds
# k= 23 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.26555776596069336  seconds
# k= 24 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.23583984375  seconds
# k= 25 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.2614424228668213  seconds
# k= 26 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3234577178955078  seconds
# k= 27 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.28332996368408203  seconds
# k= 28 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3055760860443115  seconds
# k= 29 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.32793092727661133  seconds
# k= 30 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.28398942947387695  seconds
# k= 31 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.26894092559814453  seconds
# k= 32 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.36068010330200195  seconds
# k= 33 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.30443882942199707  seconds
# k= 34 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3131084442138672  seconds
# k= 35 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3142414093017578  seconds
# k= 36 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3200361728668213  seconds
# k= 37 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.31286120414733887  seconds
# k= 38 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3128814697265625  seconds
# k= 39 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3378012180328369  seconds
# k= 40 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.32976746559143066  seconds
# k= 41 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3884434700012207  seconds
# k= 42 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.33420848846435547  seconds
# k= 43 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.381115198135376  seconds
# k= 44 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.5583932399749756  seconds
# k= 45 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.40897440910339355  seconds
# k= 46 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3809013366699219  seconds
# k= 47 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.37078237533569336  seconds
# k= 48 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.4297921657562256  seconds
# k= 49 ====================================================================================================
#
# using NGT, Proximity matrix has been calculated  in:  0.3897879123687744  seconds
# k= 50 ====================================================================================================
